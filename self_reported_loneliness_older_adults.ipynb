# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('self-reported-loneliness-older-adults new.csv')

# %%
df.head()
# Out:
#    country siglas  Year  \
# 0  Finland    FIN  2002
# 1  Austria    AUT  2005
# 2  Belgium    BEL  2005
# 3  Denmark    DNK  2005
# 4   France    FRA  2005
#
#    Self-reported feelings of loneliness among older adults
# 0                                                 39
# 1                                                 46
# 2                                                 42
# 3                                                 25
# 4                                                 45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   country                                                  15 non-null     object
#  1   siglas                                                   15 non-null     object
#  2   Year                                                     15 non-null     int64
#  3   Self-reported feelings of loneliness among older adults  15 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 608.0+ bytes

# %%
 df.describe()
# Out:
#               Year  Self-reported feelings of loneliness among older adults
# count    15.000000                                          15.000000
# mean   2006.533333                                          39.000000
# std       4.718757                                           9.827076
# min    2002.000000                                          25.000000
# 25%    2005.000000                                          31.500000
# 50%    2005.000000                                          39.000000
# 75%    2005.000000                                          45.500000
# max    2018.000000                                          62.000000

# %% [markdown]
# # eda

# %%
from matplotlib import pyplot as plt
df['Self-reported feelings of loneliness among older adults'].plot(kind='line', figsize=(8, 4), title='Self-reported feelings of loneliness among older adults')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
mean_loneliness = df.groupby('country')['Self-reported feelings of loneliness among older adults'].mean()

# Define a color palette with enough colors for each country
colors = sns.color_palette('pastel', len(mean_loneliness))

# Plot the horizontal bar chart with the specified color palette
mean_loneliness.plot(kind='barh', color=colors)

# Add labels and title
plt.xlabel('Mean Loneliness Score')
plt.ylabel('Country')
plt.title('Loneliness by Country')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y='Self-reported feelings of loneliness among older adults', data=df)
plt.title('Distribution of Loneliness Feelings')
plt.ylabel('Feelings of Loneliness')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Self-reported feelings of loneliness among older adults'], bins=5, kde=True)
plt.title('Histogram of Loneliness Feelings')
plt.xlabel('Feelings of Loneliness')
plt.ylabel('Frequency')
plt.show()

# %%
df['Year'].plot(kind='line', figsize=(8, 4), title='Year')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.show()

# %% [markdown]
# #  heatmap

# %%
 # prompt: make a heatmap for country and loneliness

import seaborn as sns
import matplotlib.pyplot as plt

pivot_table = df.pivot_table(values='Self-reported feelings of loneliness among older adults', index='country')

sns.heatmap(pivot_table, cmap='coolwarm', annot=True)
plt.title('Loneliness by Country')
plt.show()
